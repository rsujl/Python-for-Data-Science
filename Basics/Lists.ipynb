# %% [markdown]
# ### Lists

# %%
lst=[]

# %%
lst
# Out:
# []

# %%
lst.append(10)

# %%
lst
# Out:
# [10]

# %%
10 in lst
# Out:
# True

# %%
10 not in lst
# Out:
# False

# %%
for i in lst:
    print(i)
# Out:
# 10
# 10
# 20

# %%
lst.append(20)

# %%
lst
# Out:
# [10, 10, 20]

# %%
list()
# Out:
# []

# %%
numlst=list()
while True:
    inp=input("Enter number")
    if inp.lower() == 'done':
        break
    else:
        value=int(inp)
        numlst.append(value)
print(numlst)
# Out:
# Enter number 1
# Enter number 2
# Enter number 3
# Enter number done
# [1, 2, 3]
