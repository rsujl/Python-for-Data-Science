# %%
print("*****")
# Out:
# *****

# %%
for i in range(5):
    print("*",end='')
# Out:
# *****

# %% [markdown]
# ### Square Pattern

# %%
n=5
for i in range(n):
    for j in range(n):
        print("*",end='')
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %% [markdown]
# ### Right Angle Triangle

# %%
n=int(input("Enter n"))
def rightTriangle(n):
    for i in range(n):
        for j in range(i+1):
            print("*",end='')
        print()
rightTriangle(n)
# Out:
# Enter n 6
# *
# **
# ***
# ****
# *****
# ******

# %% [markdown]
# ### Backward Right Angle Triangle

# %%
n=int(input("Enter n"))
def backwardTriangle(n):
    for i in range(n):
        for j in range(n-i):
            print("*",end='')
        print()
backwardTriangle(n)
# Out:
# Enter n 5
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ### Pyramid Pattern

# %%
n=int(input("Enter n"))
def Pyramid(n):
    for i in range(1,n+1):
        for j in range(n-i):
            print(" ",end=" ")
        for k in range(1,2*i):
            print("*",end=" ")
        print()
Pyramid(n)
# Out:
# Enter n 5
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
rows = int(input("Enter the row size for the pattern: "))
for i in range(1, rows + 1):  # Outer loop for rows
    for j in range(rows  - i):  # Inner loop for spaces
        print(" ", end=" ")
    for k in range(1, 2 * i):  # Inner loop for stars
        print("*", end=" ")
    print()
# Out:
# Enter the row size for the pattern:  5
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
def pattern(n):
    for i in range(n):
        for j in range(n-i):
            print(" ",end=" ")
        for k in range(1,2*i):
            print("*",end=" ")
# Out:
#   Cell In[3], line 1
#     def pattern(n):
#                    ^
# _IncompleteInputError: incomplete input

# %%
name="Sujal"

# %%
name
# Out:
# 'Sujal'

# %%
print(name)

# %%
def prime(n):
    if n%2!=0:
        print("Not prime")
    else:
        print("Prime")
prime(9)
# Out:
# Not prime
