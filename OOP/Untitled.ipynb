# %%
class Student:
    def __init__(self):
        self.student=[]
        self.menu()
    def menu(self):
        print(
            f"Enter 1 to Add student \n"
            f"Enter 2 to display student \n"
            f"Enter 3 to edit student \n"
            f"Enter 4 to delete student \n"
            f"Enter 0 to End \n"
        )
        choice=int(input("Enter Above choice to continue"))
        match choice:
            case 1:
                self.addStudent()
            case 2:
                self.dispStudent()
            case 3:
              self.editStudent()
            case 4:
                # delete student
                pass
            case _:
                exit()
                print("Operation Completed")
    def addStudent(self):
        id=int(input("Enter id"))
        name=input("Enter name")
        age=int(input("Enter age"))
        course=input("Enter course")
        stu={
            "id":id,
            "name":name,
            "age":age,
            "course":course
        }
        self.student.append(stu)
        print(f"Id is {id} Name is {name} Age is {age} Course is {course}")
        self.menu()
    def dispStudent(self):
        print(self.student)
        self.menu()      
s1=Student()
# Out:
# Enter 1 to Add student
# Enter 2 to display student
# Enter 3 to edit student
# Enter 4 to delete student
# Enter 0 to End
# Enter Above choice to continue 1
# Enter id 1
# Enter name sujal
# Enter age 21
# Enter course 0
# Id is 1 Name is sujal Age is 21 Course is 0
# Enter 1 to Add student
# Enter 2 to display student
# Enter 3 to edit student
# Enter 4 to delete student
# Enter 0 to End
# Enter Above choice to continue 0
# Operation Completed

# %%
class Person:
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender
def greet(p):
    print(f"Hello my is {p.name } and gender is {p.gender}")
p1=Person("Sujal","Male")
greet(p1)
# Out:
# Hello my is Sujal and gender is Male

# %%
lst=[]
n=1
while n<=5:
    name=input("Enter name")
    age=input("Enter age")
    n+=1
    newLst=[name,age]
    lst.append(newLst)
print(lst)
# Out:
# Enter name sujal
# Enter age 21
# Enter name mynk
# Enter age 20
# Enter name taksh
# Enter age 21
# Enter name sujal
# Enter age 33
# Enter name drash
# Enter age 23
# [['sujal', '21'], ['mynk', '20'], ['taksh', '21'], ['sujal', '33'], ['drash', '23']]

# %%
class Menu:
    def show_menu(self):
        print(
        f"Hii How can i help you today !!!! \n"
        f"Press 1 to Sign Up \n"
        f"Press 2 to Login \n"
        f"Press 3 to Register \n"
        f"Press 4 to exit \n"
        )
        user_choice=int(input("Enter choice"))
        match user_choice:
            case 1:
                SignUp()
            case 2:
                pass
            case 3:
                pass
            case 4:
                exit()
class SignUp:
    def __init__(self):
        print("Welcome to Sign Up !!!!")
        self.students=[]
        self.id=''
        self.userName=''
        self.userPassword=''
        user_id=int(input("Enter user id"))
        user_name=input("Enter user name")
        user_pass=input("Enter user password")
        self.id=user_id
        self.userName=user_name
        self.userPassword=user_pass
        print(f"Id is {self.id} Name is {self.userName} and Password is {self.userPassword}")
class LoginUp:
    pass
    
class Register:
    pass
class admin:
    pass

# %%
m=Menu()
m.show_menu()
# Out:
# Hii How can i help you today !!!!
# Press 1 to Sign Up
# Press 2 to Login
# Press 3 to Register
# Press 4 to exit
# Enter choice 1
# Welcome to Sign Up !!!!
# Enter user id 1
# Enter user name Sujal
# Enter user password 1234
# Id is 1 Name is Sujal and Password is 1234

# %%
m

# %%
s=SignUp()
s
# Out:
# Enter user id 0
# Enter user name 0
# Enter user password 0
# Id is 0 Name is 0 and Password is 0
