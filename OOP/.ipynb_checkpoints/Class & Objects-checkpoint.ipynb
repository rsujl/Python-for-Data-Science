# %%
class Atm:
     def __init__(self):
         self.pin=''
         self.balance=0
         self.menu()
     def menu(self):
        user_input=input(
            f"hi how can i help you \n"
            f"Press 1 to create Pin \n"
            f"Press 2 to change pin \n"
            f"Press 3 to check balance \n"
            f"Press 4 to to withdraw \n"
            f"Anyhting else to Exit"
        )
        if user_input == "1":
            self.createPin()
        elif user_input == "2":
            self.changePin()
        elif user_input == "3":
            self.checkBalance()
        elif user_input == "4":
            self.withdrawBalance()
        else:
            exit()

# %%
def createPin(self):
    user_pin=input("Enter Pin")
    self.pin=user_pin
    user_balance=int(input("Enter balance"))
    self.balance=user_balance
    print("Pin created Successfully")
    print(self.pin)
    print(self.balance)
    self.menu()

# %%
Atm.createPin=createPin

# %%
def changePin(self):
    old_pin=input("Enter Old pin")
    if old_pin == self.pin:
        newPin=input("Enter New Pin")
        self.pin=newPin
        print("New Pin is",newPin)
        self.menu()

# %%
Atm.changePin=changePin

# %%
def checkBalance(self):
    user_pin=input("Enter Pin")
    if user_pin==self.pin:
        print("Balance is",self.balance)
        self.menu()
    else:
        print("Invalid Pin")
        self.menu()

# %%
Atm.checkBalance=checkBalance

# %%
def withdrawBalance(self):
    user_pin=input("Enter Pin")
    if user_pin==self.pin:
        useramt=input("Enter amount to withdraw")
        self.balance=int(self.balance)-int(useramt)
        print("Amount Debited",useramt)
        print("Remaining Amount",self.balance)
    else:
        print("Invalid Pin")

# %%
Atm.withdrawBalance=withdrawBalance

# %%
obj=Atm()
# Out:
# hi how can i help you
# Press 1 to create Pin
# Press 2 to change pin
# Press 3 to check balance
# Press 4 to to withdraw
# Anyhting else to Exit 1
# Enter Pin 12
# Enter balance 3000
# Pin created Successfully
# 12
# 3000
# hi how can i help you
# Press 1 to create Pin
# Press 2 to change pin
# Press 3 to check balance
# Press 4 to to withdraw
# Anyhting else to Exit 2
# Enter Old pin 12
# Enter New Pin 34
# New Pin is 34
# hi how can i help you
# Press 1 to create Pin
# Press 2 to change pin
# Press 3 to check balance
# Press 4 to to withdraw
# Anyhting else to Exit 3
# Enter Pin 34
# Balance is 3000
# hi how can i help you
# Press 1 to create Pin
# Press 2 to change pin
# Press 3 to check balance
# Press 4 to to withdraw
# Anyhting else to Exit 2
# Enter Old pin 34
# Enter New Pin 12
# New Pin is 12
# hi how can i help you
# Press 1 to create Pin
# Press 2 to change pin
# Press 3 to check balance
# Press 4 to to withdraw
# Anyhting else to Exit 4
# Enter Pin 14
# Invalid Pin
