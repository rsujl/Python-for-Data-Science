# %%
class Student:
    def __init__(self):
        self.student=[]
        self.menu()
    def menu(self):
        print(
            f"Enter 1 to Add student \n"
            f"Enter 2 to display student \n"
            f"Enter 3 to edit student \n"
            f"Enter 4 to delete student \n"
            f"Enter 0 to End \n"
        )
        choice=int(input("Enter Above choice to continue"))
        match choice:
            case 1:
                self.addStudent()
            case 2:
                self.dispStudent()
            case 3:
              self.editStudent()
            case 4:
                # delete student
                pass
            case _:
                exit()
                print("Operation Completed")
    def addStudent(self):
        id=int(input("Enter id"))
        name=input("Enter name")
        age=int(input("Enter age"))
        course=input("Enter course")
        stu={
            "id":id,
            "name":name,
            "age":age,
            "course":course
        }
        self.student.append(stu)
        print(f"Id is {id} Name is {name} Age is {age} Course is {course}")
        self.menu()
    def dispStudent(self):
        print(self.student)
    def editStudent(self):
        user_id=int(input("Enter id to search"))
        if user_id==id:
            print("Id Found enter updated details")
            newUserId=int(input("Enter new id"))
            newuserName=input("Enter Username")
            newAge=int(input("Enter Age"))
            newCourse=input("Enter new Course")
            id=newUserID
            name=newUserName
            age=newAge
            course=newCourse
        else:
            print("Id not found")
        
s1=Student()
# Out:
# Enter 1 to Add student
# Enter 2 to display student
# Enter 3 to edit student
# Enter 4 to delete student
# Enter 0 to End
# Enter Above choice to continue 1
# Enter id 1
# Enter name sujal
# Enter age 21
# Enter course mtech
# Id is 1 Name is sujal Age is 21 Course is mtech
# Enter 1 to Add student
# Enter 2 to display student
# Enter 3 to edit student
# Enter 4 to delete student
# Enter 0 to End
# Enter Above choice to continue 1
# Enter id 2
# Enter name taksh
# Enter age 21
# Enter course arts
# Id is 2 Name is taksh Age is 21 Course is arts
# Enter 1 to Add student
# Enter 2 to display student
# Enter 3 to edit student
# Enter 4 to delete student
# Enter 0 to End
# Enter Above choice to continue 2
# [{'id': 1, 'name': 'sujal', 'age': 21, 'course': 'mtech'}, {'id': 2, 'name': 'taksh', 'age': 21, 'course': 'arts'}]
