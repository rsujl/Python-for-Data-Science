# %%
student={
    "name":"Sujal",
    "age":20,
    "id":1
}
print(student)
student["name"]
# Out:
# {'name': 'Sujal', 'age': 20, 'id': 1}
# 'Sujal'

# %%
student["course"]="Python"

# %%
student
# Out:
# {'name': 'Sujal', 'age': 20, 'id': 1}

# %%
student['age']=30

# %%
del student["age"]

# %%
student.pop("course")
# Out:
# 'Python'

# %%
student.popitem()
# Out:
# ('id', 1)

# %%
print("id" in student)
# Out:
# True

# %%
print(student.get("city","city not found"))
# Out:
# city not found

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'id'])

# %%
student.values()
# Out:
# dict_values(['Sujal', 20, 1])

# %%
student.items()
# Out:
# dict_items([('name', 'Sujal'), ('age', 20), ('id', 1)])

# %%
for key in student:
    print(key)
# Out:
# name
# age
# id

# %%
for value in student.values():
    print(value)
# Out:
# Sujal
# 20
# 1

# %%
for key,value in student.items():
     print(f"{key} and {value}")
# Out:
# name and Sujal
# age and 20
# id and 1

# %%
lst=[{
    "name":"Sujal",
    "age":20,
    "course":"pyhton"
},
    {
        "name":"mynk",
        "age":30,
        "course":"civil"
    },
    {
        "name":"Taksh",
        "age":21,
        "course":"science"
    }]

# %%
print(lst[0])
# Out:
# {'name': 'Sujal', 'age': 20, 'course': 'pyhton'}

# %%
print(lst[0].keys())
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
print(lst[0].values())
# Out:
# dict_values(['Sujal', 20, 'pyhton'])

# %%
print(lst[0].items())
# Out:
# dict_items([('name', 'Sujal'), ('age', 20), ('course', 'pyhton')])

# %%
for name in lst:
    print(name["name"])
# Out:
# Sujal
# mynk
# Taksh

# %%
for name in lst:
    print(name["name"] ,"==>",name['age'])
# Out:
# Sujal ==> 20
# mynk ==> 30
# Taksh ==> 21
