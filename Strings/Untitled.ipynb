# %%
name="Sujal"

# %%
name
# Out:
# 'Sujal'

# %%
name="Sjaalalalalal"
ctn=0
for i in name:
    ctn+=1
print(f"Total letters are{ctn}")
# Out:
# Total letters are13

# %%
name=input("Enter name")
ctn=0
for i in name:
    if i in"aeiouAEIOU":
        ctn+=1
print(f"Vowels are {ctn}")
# Out:
# Enter name banana
# Vowels are 3

# %%
name="sujal"
name=name-100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 name="sujal"
# ----> 2 name=name-100
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
name=int(sujal)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 name=int(sujal)
#
# NameError: name 'sujal' is not defined

# %%
len("sja")
# Out:
# 3

# %%
name="sujal"
index=0
while index<len(name):
    x=name[index]
    print(index,x)
    index+=1print(index)
# Out:
# 0 s
# 1 u
# 2 j
# 3 a
# 4 l
# 5

# %%
name="sujal"
for index,i in enumerate(name):
    print(i,index)
# Out:
# s 0
# u 1
# j 2
# a 3
# l 4

# %%
name="sujal is busy"
name[::-1]
# Out:
# 'ysub si lajus'

# %%
name[4:1:-2]
# Out:
# 'lj'

# %%
name[6:30]
# Out:
# 'is busy'

# %%
name[0:30:3]
# Out:
# 'saiby'

# %%
name="banananb"
if name<"banana":
    print("comes before banana")
elif name>"banana":
    print("comes after banana")
else:
    print("All right banana")
# Out:
# comes after banana

# %%
name="ssuujal"
name.find('s',1)
# Out:
# 1

# %%
x = 'From marquard@uct.ac.za'
x[8]
# Out:
# 'q'

# %%
x[14:17]
# Out:
# 'uct'

# %%
for letter in 'banana':
    print(letter)
# Out:
# b
# a
# n
# a
# n
# a

# %%
print(len("banana")*7)
# Out:
# 42

# %%
text = "X-DSPAM-Confidence:    0.8475"
position=text.find(":")
value=text[position+1:]
ans=float(value)
print(ans)
# Out:
# 0.8475
