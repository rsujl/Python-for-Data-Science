# %%
file=open("sujal.txt",'x')

# %%
file
# Out:
# <_io.TextIOWrapper name='sujal.txt' mode='x' encoding='cp1252'>

# %%
file=open("sujal.txt")

# %%
file=open("sujal.txt","r")

# %%
data=file.read(30)
print(data)
# Out:
# hello my nme is sujal

# %%
file=open("certificate.txt","x")

# %%
file=open("certificate.txt","r")

# %%
data=file.read()

# %%
print(data)
# Out:
# scorname=sujal

# %%
data=data.lower()

# %%
print(data)
# Out:
# scorname=sujal

# %%
if "live" in data:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
file=open("abc.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 file=open("abc.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
file=open("name.txt","w")

# %%
file.write("hello myname is shal")
# Out:
# 20

# %%
file.close()

# %%
file=open("name.txt","a")
file.write("hello")
# Out:
# 5

# %%
import shutil
